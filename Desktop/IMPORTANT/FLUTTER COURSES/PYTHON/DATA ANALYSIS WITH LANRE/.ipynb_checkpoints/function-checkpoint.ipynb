# %%
print()# this is referred to as function 
""""types of fuctions 
    in built functions
    user defined function 
    third party function """

def greeting(name): #function keyword function_name bracket
    print(f"Hello {name}") #function body 

name = input("What's is your name? ")
greeting(name.upper())
# Out:
# What's is your name?  OPeyemi
# Hello OPEYEMI

# %%
"""a program to get the square of a number 
    find the hypothenus of a triange using the 
    fomular 0.5*(a**2 + b**2)""" 

    
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))

c =  (square(a) + square(b))** 0.5
print(f"The Hypotenus of the triangle is {c}")
# Out:
# Enter the value of a:  5
# Enter the value of b:  4
# The Hypotenus of the triangle is 6.4031242374328485

# %%
def square(x):
    square = x**2
    return square
