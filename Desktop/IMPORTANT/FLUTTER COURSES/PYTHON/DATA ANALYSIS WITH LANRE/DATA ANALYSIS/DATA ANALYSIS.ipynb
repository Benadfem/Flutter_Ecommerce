# %% [markdown]
# data analysis is the collection of data for informational purposes. so as to determine decision making in
# ensuring accurate and effective and productive output.
#
# Types of data
# 1. Numeric data
# 2. alpha-numeric data
# 3. Alphabetical data.
#
# sources of data
# internet, interview, history,
#
#  form of data
# structured data
# unstructured data
#
# structured data
# Tabular data
# a well arranged data. that is created in form of spread sheet
# row: observation
# column: features
#
# Tabular data: example real-state-in-ajah
# house_number, price, size: are called labels
#
# we are going to use kaggle.com to get data that we can work with
# we can have a structured data in python with
# List and Dictionary

# %%
#create a list of house_details
house = [1254,456,245,487,4541]# a list can be called a series. 
house_compare = house[0]- house[1]
house_compare
# Out:
# 798

# %% [markdown]
# A nested list. this is a list of list
# meaning having list as the element of an index
#
# example is
# houses_nested_list = [
#     [115910.26, 128.0, 4.0],
#     [48718.17, 210.0, 3.0],
#     [28977.56, 58.0, 2.0],
#     [36932.27, 79.0, 3.0],
#     [83903.51, 111.0, 3.0],
# ]

# %%
houses_nested_list = [
    [115910.26, 128.0, 4.0],
    [48718.17, 210.0, 3.0],
    [28977.56, 58.0, 2.0],
    [36932.27, 79.0, 3.0],
    [83903.51, 111.0, 3.0],
]
type(houses_nested_list)# this will display data type of the variable list 
len(houses_nested_list)# this will display the length of the list 
houses_nested_list
for house in houses_nested_list: # it iterated inside the outter list
    for index in house:#it iterates inside the inner list 
        print(index)#this is the index of the inner list
    print()#this runs outside the inner loop to create a new line
    print("next house_values")
# Out:
# 115910.26
# 128.0
# 4.0
#
# next house_values
# 48718.17
# 210.0
# 3.0
#
# next house_values
# 28977.56
# 58.0
# 2.0
#
# next house_values
# 36932.27
# 79.0
# 3.0
#
# next house_values
# 83903.51
# 111.0
# 3.0
#
# next house_values

# %% [markdown]
# we can decide to get the price_per_m2 (this denotes price per meter square of a particular house
# in the estate)
# price_per_m2 = price_of_house / surface_area_of_house

# %%
#create a list and add the price_per_m2 value to the list
house_list = [115910.26, 128.0, 4.0]
price_per_m2 = house_list[0] / house_list[1]
house_list.append(round(price_per_m2, 2))
house_list
# Out:
# [115910.26, 128.0, 4.0, 905.55]

# %% [markdown]
# since List does not present the data as expected enough
# because it only shows the value and not the feature of the
# dataset,
# a dictionary is introduced to help solve this problem

# %%
house_dict = {
    "price_of_house":115910.26,
    "surface_area_of_house" :128,
    "numbers_of_rooms": 4,
    "price_per_m2": 905.55
} # this is an example of a dictionary 
type(house_list)
house_list["price_of_house"]

#to add a new data in a dictionary
house_dict["house_color"] = "Green"
house_dict
# Out:
# {'price_of_house': 115910.26,
#  'surface_area_of_house': 128,
#  'numbers_of_rooms': 4,
#  'price_per_m2': 905.55,
#  'house_color': 'Green'}

# %%
for key,value in house_list.items():
    print(f"{key} :  {value}")
# Out:
# price_of_house :  115910.26
# surface_area_of_house :  128
# numbers_of_rooms :  4
# price_per_m2 :  905.55

# %%
house_dict = [
   {
        "price_approx_usd":115910.26,
        "surface_covered_in_m2" :128,
        "rooms": 4,
       ""
    },
    {
        "price_approx_usd": 115910.26,
        "surface_covered_in_m2": 128,
        "rooms": 4,
    },
    {
        "price_approx_usd": 48718.17,
        "surface_covered_in_m2": 210,
        "rooms": 3,
    },
    {
        "price_approx_usd": 28977.56,
        "surface_covered_in_m2": 58,
        "rooms": 2,
    },
    {
        "price_approx_usd": 36932.27,
        "surface_covered_in_m2": 79,
        "rooms": 3,
    },
    {
        "price_approx_usd": 83903.51,
        "surface_covered_in_m2": 111,
        "rooms": 3,
    },
]
house_dict
for house in house_dict:
    print(house)
# Out:
# {'price_approx_usd': 115910.26, 'surface_covered_in_m2': 128, 'rooms': 4}
# {'price_approx_usd': 115910.26, 'surface_covered_in_m2': 128, 'rooms': 4}
# {'price_approx_usd': 48718.17, 'surface_covered_in_m2': 210, 'rooms': 3}
# {'price_approx_usd': 28977.56, 'surface_covered_in_m2': 58, 'rooms': 2}
# {'price_approx_usd': 36932.27, 'surface_covered_in_m2': 79, 'rooms': 3}
# {'price_approx_usd': 83903.51, 'surface_covered_in_m2': 111, 'rooms': 3}

# %%
for house in house_dict:
    for key, value in house.items():
        print(f"{key} : {value}")
    print()
# Out:
# price_approx_usd : 115910.26
# surface_covered_in_m2 : 128
# rooms : 4
#
# price_approx_usd : 115910.26
# surface_covered_in_m2 : 128
# rooms : 4
#
# price_approx_usd : 48718.17
# surface_covered_in_m2 : 210
# rooms : 3
#
# price_approx_usd : 28977.56
# surface_covered_in_m2 : 58
# rooms : 2
#
# price_approx_usd : 36932.27
# surface_covered_in_m2 : 79
# rooms : 3
#
# price_approx_usd : 83903.51
# surface_covered_in_m2 : 111
# rooms : 3
